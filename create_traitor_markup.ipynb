# %% [markdown]
# # Create Traitor Markup
#
# This notebook creates the traitor md file markup that is used on the main Readme.md file. After I run this process I just copy the markup to the main Readme.md.

# %%
import pandas as pd
import io
import requests

# %%
traitor_df = pd.read_csv("147_traitors.csv", index_col=False)

# %%
traitor_df
# Out:
#     open_secrets_id           full_name first_name   last_name  state chamber  \
# 0         N00003028  Robert B. Aderholt     Robert    Aderholt   Ala.  House
# 1         N00030910           Mo Brooks         Mo      Brooks   Ala.  House
# 2               NaN          Jerry Carl      Jerry        Carl   Ala.  House
# 3               NaN         Barry Moore      Barry       Moore   Ala.  House
# 4         N00035691         Gary Palmer       Gary      Palmer   Ala.  House
# ..              ...                 ...        ...         ...    ...     ...
# 142       N00034044        John Kennedy       John     Kennedy    La.  Senate
# 143       N00043298    Cindy Hyde-Smith      Cindy  Hyde-Smith  Miss.  Senate
# 144       N00041620         Josh Hawley       Josh      Hawley    Mo.  Senate
# 145       N00033085            Ted Cruz        Ted        Cruz  Texas  Senate
# 146       N00029788      Cynthia Lummis    Cynthia      Lummis   Wyo.  Senate
#
# ...

# %%
traitor_df = traitor_df.fillna('')

# %%
traitor_df
# Out:
#     open_secrets_id           full_name first_name   last_name  state chamber  \
# 0         N00003028  Robert B. Aderholt     Robert    Aderholt   Ala.  House
# 1         N00030910           Mo Brooks         Mo      Brooks   Ala.  House
# 2                            Jerry Carl      Jerry        Carl   Ala.  House
# 3                           Barry Moore      Barry       Moore   Ala.  House
# 4         N00035691         Gary Palmer       Gary      Palmer   Ala.  House
# ..              ...                 ...        ...         ...    ...     ...
# 142       N00034044        John Kennedy       John     Kennedy    La.  Senate
# 143       N00043298    Cindy Hyde-Smith      Cindy  Hyde-Smith  Miss.  Senate
# 144       N00041620         Josh Hawley       Josh      Hawley    Mo.  Senate
# 145       N00033085            Ted Cruz        Ted        Cruz  Texas  Senate
# 146       N00029788      Cynthia Lummis    Cynthia      Lummis   Wyo.  Senate
#
# ...

# %%
header = 'Photo | Name | State | Chamber | Donors | Twitter | Fired | Demands  \n'
separator = '------------ | ------------ | ------------- | ------------- | ------------- | ------------- | ------------- | -------------\n'

f = open("traitors.md", "w")
f.write(header)
f.write(separator)


for _, traitor_row in traitor_df.iterrows():     

    donor_link = 'n/a'
    if traitor_row.open_secrets_id:
        donor_link = f'[List]({traitor_row.top_donors_link})'
    photo_img = f'<img src="https://github.com/147-Project/147-republican-traitors/blob/master/photos/{traitor_row.picture}?raw=true" width="40" height="40">'
    
    f.write(f'{photo_img} | {traitor_row.full_name} | {traitor_row.state} | {traitor_row.chamber}| {donor_link} | @{traitor_row.twitter} | no | no\n')

f.close()

#open and read the file after the appending:
f = open("traitors.md", "r")
print(f.read())
# Out:
# Photo | Name | State | Chamber | Donors | Twitter | Fired | Demands
# ------------ | ------------ | ------------- | ------------- | ------------- | ------------- | ------------- | -------------
# <img src="https://github.com/147-Project/147-republican-traitors/blob/master/photos/robert_b._aderholt.png?raw=true" width="40" height="40"> | Robert B. Aderholt | Ala. | House | [List](https://www.opensecrets.org/members-of-congress/robert-aderholt/contributors?cid=N00003028&cycle=2020&recs=100&type=C) | @Robert_Aderholt | no | no
# <img src="https://github.com/147-Project/147-republican-traitors/blob/master/photos/mo_brooks.png?raw=true" width="40" height="40"> | Mo Brooks | Ala. | House | [List](https://www.opensecrets.org/members-of-congress/mo-brooks/contributors?cid=N00030910&cycle=2020&recs=100&type=C) | @RepMoBrooks | no | no
# ...
